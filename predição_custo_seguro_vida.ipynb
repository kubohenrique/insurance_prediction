# %% [markdown]
# <a href="https://colab.research.google.com/github/kubohenrique/insurance_prediction/blob/main/predi%C3%A7%C3%A3o_custo_seguro_vida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROJETO REGRESSÃO
#
# Como falamos antes, nossos templates ficarão cada vez mais simples!!
#
# O objetivo deste projeto é desenvolver um projeto de Regressão para prever o custo do Seguro de Vida, com [esses dados do Kaggle](https://www.kaggle.com/annetxu/health-insurance-cost-prediction).
#
# Aqui, queremos, como sempre, trazer o máximo de autonomia e independência pra vocês. Façam o download, e disponibilizem os seus dados, carreguem eles aqui, e desenvolvam o projeto.
#
# ## Objetivos
#
# * Adquirir e disponibilizar os dados
# * Análise completa dos dados e do problema (Na mão, ou com Pandas Profiling, SweetViz, etc)
# * Desenvolver uma solução de Machine Learning eficiente com PyCaret para Regressão
#
# LEMBREM-SE: Documentação, Storytelling, Artigo com Código!
#
# Mãos à obra e boa sorte!

# %% [markdown]
# # **PROJETO DE PREDIÇÃO DE CUSTOS DE SEGURO DE VIDA**
#
# <p align="center"><img src="https://image.freepik.com/vetores-gratis/seguro-protecao-contra-perdas-financeiras-gerenciamento-de-riscos-seguro-de-saude-vida-propriedade-e-renda_335657-839.jpg" width="40%"></p>
#
#
# **O que é o seguro de vida ?**
#
# O seguro de vida é um contrato feito com uma seguradora para proteger o beneficiário de acidentes ou imprevistos. Nesse caso específico, o seguro de vida garante que os beneficiários do contrato receberão um valor financeiro em caso de morte do titular, que é a pessoa que fez o seguro.
#
# Na maioria dos casos, o seguro de vida também cobre situações em que o titular sofre algum acidente e se torna impossibilitado de trabalhar, para esses casos, há uma cobertura por invalidez.
#
# O seguro de vida é um instrumento poderoso para auxiliar não só no planejamento de independência financeira, como também na tranquilidade e estabilidade em qualquer cenário.
#
# **Como funciona o seguro de vida ?**
#
# O seguro de vida é uma espécie de “fundo” em que o titular paga uma quantia mensal, semestral ou única, dependendo dos termos acordados.
#
# Assim, a seguradora paga uma indenização aos beneficiários ou aos dependentes legais do titular caso aconteça uma das situações previstas no contrato (sinistros), que podem ser:
#
# * Morte
# * Invalidez permanente
# * Doença grave
# * Internação
# * Incapacidade temporária
#
# Ao contratar um seguro de vida, o titular decide quem são os beneficiários, quais situações serão cobertas e qual será o prazo de validade, que pode ser vitalício ou não.
#
# O contrato também definirá se a indenização será paga em um valor único ou uma renda periódica, e ainda se haverá possibilidade de resgatar o montante a qualquer hora.
#
# Todas estas condições ficam registradas na apólice, que oficializa o contrato de seguro de vida.
#
# A apólice é um documento de extrema importância, pois é ela que irá garantir os direitos do titular e dos beneficiários quando for necessário cobrar a indenização da seguradora.
#
# No Brasil, esse setor é regulado e fiscalizado pela Superintendência de Seguros Privados (Susep), que autoriza quais seguradoras podem oferecer este tipo de contrato.
#
# **Para que serve o seguro de vida ?**
#
# Em resumo, o seguro de vida serve para dar um auxílio financeiro que é de imensa ajuda no momento em que a família está mais abalada e vulnerável pela perda de alguém querido.

# %% [markdown]
# **O que é o seguro de vida ?**
#
# O seguro de vida é um contrato feito com uma seguradora para proteger o beneficiário de acidentes ou imprevistos. Nesse caso específico, o seguro de vida garante que os beneficiários do contrato receberão um valor financeiro em caso de morte do titular, que é a pessoa que fez o seguro.
#
# Na maioria dos casos, o seguro de vida também cobre situações em que o titular sofre algum acidente e se torna impossibilitado de trabalhar, para esses casos, há uma cobertura por invalidez.
#
# O seguro de vida é um instrumento poderoso para auxiliar não só no planejamento de independência financeira, como também na tranquilidade e estabilidade em qualquer cenário.
#
# **Como funciona o seguro de vida ?**
#
# O seguro de vida é uma espécie de “fundo” em que o titular paga uma quantia mensal, semestral ou única, dependendo dos termos acordados.
#
# Assim, a seguradora paga uma indenização aos beneficiários ou aos dependentes legais do titular caso aconteça uma das situações previstas no contrato (sinistros), que podem ser:
#
# * Morte
# * Invalidez permanente
# * Doença grave
# * Internação
# * Incapacidade temporária
#
# Ao contratar um seguro de vida, o titular decide quem são os beneficiários, quais situações serão cobertas e qual será o prazo de validade, que pode ser vitalício ou não.
#
# O contrato também definirá se a indenização será paga em um valor único ou uma renda periódica, e ainda se haverá possibilidade de resgatar o montante a qualquer hora.
#
# Todas estas condições ficam registradas na apólice, que oficializa o contrato de seguro de vida.
#
# A apólice é um documento de extrema importância, pois é ela que irá garantir os direitos do titular e dos beneficiários quando for necessário cobrar a indenização da seguradora.
#
# No Brasil, esse setor é regulado e fiscalizado pela Superintendência de Seguros Privados (Susep), que autoriza quais seguradoras podem oferecer este tipo de contrato.
#
# **Para que serve o seguro de vida ?**
#
# Em resumo, o seguro de vida serve para dar um auxílio financeiro que é de imensa ajuda no momento em que a família está mais abalada e vulnerável pela perda de alguém querido.
#
# <p align="center"><img src="https://image.freepik.com/vetores-gratis/funil-de-vendas-geracao-de-leads-gestao-de-clientes-estrategia-de-marketing-elemento-de-design-plano-de-conversao-de-comercio-plano-de-venda-ilustracao-do-conceito-de-filtro-de-clientes_335657-2009.jpg" width="40%"></p>
#
# Pela sua significância, é muito importante para a seguradora saber cobrar seus clientes, em um mercado com vários concorrentes, a empresa que tiver a melhor análise, saber cobrar por um preço justo seus clientes, terá uma enorme vantagem.
#
# E até bom para o próprio cliente ter ciência de que tipo de seguro cabe em seu orçamento, e assim tomar a melhor decisão sem comprometer a saúde financeira.
#
# Visando melhorar estes aspectos, nesse projeto pretendo fazer um modelo de previsão para os preços dos seguros de vida.

# %%
# !pip install pycaret -q
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# ## 0.0 - Biblioteca

# %%
# Importando as bibliotecas necessárias para o projeto

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pycaret.utils import enable_colab
from pycaret.datasets import get_data
from pycaret.regression import *
from pycaret.utils import check_metric

enable_colab()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline

    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24

    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )

sns.set()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# ### 0.1 - Importando os Dados

# %% [markdown]
# Os dados foram retirados da própria bliblioteca do Pycaret, mas é possível acessá-la através do [Kaggle](https://www.kaggle.com/annetxu/health-insurance-cost-prediction).

# %%
df = get_data('insurance')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# ## 1.0 - Descrição dos Dados
#
# Aqui vamos analisar os dados em si, verificar se há dados faltantes, os tipos de dados, a descrição estatística. Assim podemos fazer ajustes se necessários para podermos fazer o preparo dos dados para o modelo de Machine Learning.

# %% [markdown]
# ### 1.1 - Dimensão dos Dados

# %%
print('Número de linhas: {}'.format(df.shape[0]))
print('Número de colunas: {}'.format(df.shape[1]))
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# ### 1.2 - Tipos de Dados

# %%
df.dtypes
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# ### 1.3 - Verificar Valores Ausentes

# %%
df.isna().sum()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# ### 2.0 - Análise Exploratória dos Dados
#
# Depois de verificar os dados ausentes, os tipos de dados, e constatarmos que eles estão ok, vamos explorar os dados, nessa fase conseguiremos ter alguns *insights*.

# %%
df.describe().T
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# Os dados estatísticos aparentemente estão condizentes, sem nenhum outlier aparente.
#
# Vamos verificar agora a demografia do dataset, ver se tem mais homem ou mulheres, pelo gráfico vimos que é quase equivalente.

# %%
sns.countplot(df['sex']);
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# Vamos verificar agora se o valor cobrado difere entre idade e e sexo:

# %%
plt.figure(figsize=(12,6))
aux2 = df[['age', 'charges']].groupby( 'age' ).sum().reset_index()
sns.barplot( x='age', y='charges', data=aux2 );
plt.xticks(rotation=90);
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %%
aux1 = df[['sex', 'charges']].groupby( 'sex' ).sum().reset_index()
sns.barplot( x='sex', y='charges', data=aux1 );
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# * o valor cobrado por idade não é muito esclarecedor, pois pelo senso comum, quanto mais velho a pessoa, mais caro seria adquirir um seguro de vida, porém há sim uma tendencia de aumento, mas é muito pouco, e os valores mais caros são entre os jovens.
# * O valor cobrado do seguro para homens é ligeiramente superior ao cobrado de mulheres.

# %% [markdown]
# ## 3.0 - Machine Learning
#
# Aqui iremos modelar o Dataset para criarmos um algoritimo de machine learning para fazer a previsão da cobrança do seguro de vida.
#
# Por ser um modelo de previsão de preço, o mais apropriado seria usar modelos de Regressão.
#
# Utilizaremos a biblioteca Pycaret para agilizarmos a modelagem. Foi visto em etapas anteriores que o dataset não possui nenhumas anomalias e nem ouliers significativos, portanto isso facilitará o nossa trabalho.

# %% [markdown]
# ### 3.1 - Separar em teste e treino
#
# A primeira coisa a se fazer é separar o dataset em treino e teste, isso pq o teste será a parte que o modelo não vai ver, será como se esses dados de treino não estavm disponíveis quando o modelo de machine learning foi feito.
# Separarei 10% dos dados para treino.

# %%
df1 = df.copy()

test = df1.sample(frac=0.10)
train = df1.drop(test.index)

test.reset_index(inplace=True, drop=True)
train.reset_index(inplace=True, drop=True)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %%
print(train.shape)
print(test.shape)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# ### 3.2 - Setando o ambiente Pycaret
#
# A função setup() inicializa o ambiente em pycaret e cria um pipeline de transformação que prepara os dados para modelagem e deploy.
#
# Quando o setup() é executado, o algoritimo do pycaret irá automaticamente inferir todos os tipos de dados para todas as variáveis, nem sempre ele irá acertar, por isso precisamos sempre dar uma conferida.

# %%
reg = setup(data=train, target = 'charges',normalize=True, log_experiment=True, experiment_name='insurance1')
# Out:
#                                Description           Value
# 0                               session_id            6149
# 1                                   Target         charges
# 2                            Original Data       (1204, 7)
# 3                           Missing Values           False
# 4                         Numeric Features               2
# 5                     Categorical Features               4
# 6                         Ordinal Features           False
# 7                High Cardinality Features           False
# 8                  High Cardinality Method            None
# 9                    Transformed Train Set       (842, 14)
# 10                    Transformed Test Set       (362, 14)
# 11                      Shuffle Train-Test            True
# 12                     Stratify Train-Test           False
# 13                          Fold Generator           KFold
# 14                             Fold Number              10
# ...

# %% [markdown]
# ### 3.3 - Comparando modelos
#
# Comparar todos os modelos para avaliar a performance é um ponto inicial recomendado pelos desenvolvedores do PyCaret, a não ser que você saiba exatamente qual o modelo específico que você quer utilizar, o que é raramente o caso.
#
# Essa função treina todos os modelos na biblioteca do PyCaret e os avalia usando validação cruzada. Para a avaliação, a função imprime uma tabela que mostra a média do MAE, MSE, RMSE, R2, RMSLE e MAPE através dos folds (10 por padrão) de todos os modelos disponíveis na biblioteca.
#
# * MAE - Mean Absolute Error mostra a média de erro em valores absolutos.
# * MSE - Mean Squared Error, Erro Quadrático Médio
# * RMSE - Root Mean Squared Error, Raiz do Erro Quadrático Médio
# * R2 - Coefficient of Determination R2 Score
# * RMSLE - Root Mean Squared Log Error
# * MAPE - Mean Absolute Percentage Error mostra a média do erro absoluto em valores percentuais.
#
# Irei escolher o modelo baseado pelo RMSE para a metrica de avaliação

# %%
best = compare_models()
# Out:
#                                     Model        MAE           MSE       RMSE  \
# gbr           Gradient Boosting Regressor  2543.0096  2.149438e+07  4590.5300
# lightgbm  Light Gradient Boosting Machine  2744.0396  2.239799e+07  4701.2827
# rf                Random Forest Regressor  2686.3157  2.386599e+07  4861.7632
# ada                    AdaBoost Regressor  3922.9524  2.574339e+07  5048.3900
# et                  Extra Trees Regressor  2765.0497  2.706690e+07  5165.6352
# lar                Least Angle Regression  4087.0881  3.439340e+07  5843.2874
# lasso                    Lasso Regression  4089.6078  3.448853e+07  5851.8940
# ridge                    Ridge Regression  4103.0073  3.448951e+07  5852.5003
# llar         Lasso Least Angle Regression  4085.5124  3.449262e+07  5852.5265
# br                         Bayesian Ridge  4099.2095  3.449325e+07  5852.6574
# lr                      Linear Regression  4090.6335  3.449868e+07  5852.7236
# ...

# %% [markdown]
# Pelo comparativo, os dois melhores modelos são usando `gradient booster` e `random forest`, vamos escolher o Gradient Booster para esse projeto.

# %% [markdown]
# ### 3.4 - Criar o modelo
#
# `create_model` é a função mais granular no Pycaret, essa função treina e avalia o modelo usando cross validation com número de folds pre determinado.
#
# Para esse problema, usaremos o *Gradient Boosting Regressor*
#
# Há 25 regressores disponíveis na biblioteca, como vemos a seguir:

# %%
models()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# #### 3.4.1 - Instanciar o Modelo

# %%
gbr = create_model('gbr')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     2278.1392  1.565985e+07  3957.2531  0.8920  0.3936  0.2818
# 1     2166.5748  1.461595e+07  3823.0807  0.9198  0.3622  0.2341
# 2     2958.4336  2.945212e+07  5426.9804  0.7523  0.5016  0.3138
# 3     2334.9526  1.852266e+07  4303.7963  0.8674  0.4087  0.2635
# 4     2895.5232  2.638237e+07  5136.3769  0.8144  0.4237  0.3370
# 5     3204.7313  3.158776e+07  5620.2993  0.7323  0.5158  0.3801
# 6     2660.1900  2.423623e+07  4923.0310  0.8311  0.4542  0.2960
# 7     2230.8393  1.885456e+07  4342.1834  0.8871  0.4524  0.3041
# 8     2584.7764  2.234276e+07  4726.8132  0.8708  0.4625  0.2611
# 9     2115.9363  1.328957e+07  3645.4857  0.9002  0.3746  0.2937
# Mean  2543.0096  2.149438e+07  4590.5300  0.8467  0.4349  0.2965
# SD     358.4945  6.015025e+06   649.1665  0.0602  0.0488  0.0393

# %%
# verificar os parametros
print(gbr)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# ### 3.5 - Fine Tuning
#
# Quando um modelo é criado usando o create_model() ele usa os hiperparâmetros padrão para cada modelo. Para fazer o tuning desses parâmetros, usamos a função tune_model().
#
# Essa função faz o tuning dos parâmetros automaticamente, e mais uma vez o avalia com validação cruzada. O output é uma tabela de scores para MAE, MSE, RMSE, R2, RMSLE e MAPE por fold.
#
# OBS: A função tune_model() não recebe um objeto de modelo treinado como input. Ao invés disso, ela requer que o modelo passado seja uma string abreviada do modelo, como instanciamos anteriormente no create_model(). Todas as outras funções do pycaret.regression requerem um objeto de modelo treinado como argumento.

# %%
tuned_gbr = tune_model(gbr)
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     4153.5922  4.745202e+07  6888.5426  0.7093  0.4632  0.2848
# 1     2623.4556  1.638415e+07  4047.7341  0.8784  0.4622  0.4113
# 2     3910.6122  3.612442e+07  6010.3596  0.7588  0.4846  0.3527
# 3     3382.4985  2.791321e+07  5283.2950  0.8349  0.4642  0.3662
# 4     2983.3417  1.759600e+07  4194.7588  0.9046  0.4873  0.4279
# 5     2970.1290  2.501452e+07  5001.4519  0.8286  0.4455  0.3350
# 6     3151.9019  1.731715e+07  4161.3874  0.8933  0.4800  0.4712
# 7     3747.8550  3.077190e+07  5547.2422  0.7603  0.5444  0.4896
# 8     3467.6438  2.811265e+07  5302.1366  0.8482  0.4877  0.3266
# 9     3221.5014  2.186801e+07  4676.3240  0.8124  0.4715  0.4185
# Mean  3361.2531  2.685540e+07  5111.3232  0.8229  0.4791  0.3884
# SD     446.5788  9.180408e+06   854.2699  0.0605  0.0253  0.0627

# %% [markdown]
# O tune_model() é uma função que faz um random grid search dos hiperparâmetros. Por padrão, ela é configurada para otimizar o R2, mas isso pode ser modificado utilizando o parâmetro optimize.
#
# Repare como a performance melhorou!
#
# Métricas sozinhas não devem ser o único critério a ser avaliado ao finalizar o projeto e escolher o melhor modelo para produção. Outros fatores incluem tempo de treinamento, desvio padrão dos folds, entre outros.
#
# Além disso, apesar de não terem sido melhores que o GBR com os parâmetros configurados no padrão, outros modelos, após o tuning, poderiam ter tido uma melhora maior, e superado o resultado obtido aqui.

# %%
# veriificando os parâmetros
print(tuned_gbr)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# ### 3.6 - Plotando Modelos
#
# Antes de finalizar e salvar o modelo, nós podemos usar a função plot_model() para plotar visualizações sobre a performance do nosso modelo, como Residual Plots, Prediction Error, Feature Importance, etc.
#
# Essa função recebe o modelo treinado como input e retorna um plot baseado no desempenho com o pedaço do conjunto de dados separado para teste.

# %% [markdown]
# #### 3.6.1 - Plot de erro de previsão

# %%
plot_model(tuned_gbr, plot='error')

# %% [markdown]
# #### 3.6.2 - Plot das features mais importantes
#
# Outra visualização extremamente importante é a de feature_importances. Essa visualização basicamente nos mostra qual a importância de cada uma das variáveis para o resultado do modelo.
#
# Em outras palavras, estamos medindo o poder preditivo de cada variável.

# %%
# feature importances
plot_model(tuned_gbr, plot='feature')

# %% [markdown]
# ### 4.0 - Finalizando o Modelo
#
# Finalizar o modelo é o último passo do nosso projeto. Um workflow normal no PyCaret começa com o setup(), seguido do compare_models() para encontrarmos os melhores candidatos baseado nas métricas de avaliação de interesse, para então darmos seguimento com tunig de parâmetros, ensembling, stacking, etc.
#
# Esse workflow eventualmente irá levá-lo ao melhor modelo para fazer previsões em dados ainda não vistos. A função finalize_model() dá o fit no modelo, incluindo o conjunto de teste separado dentro do PyCaret anteriormente (30% nesse caso).
#
# O propósito disso é treinar o modelo no dataset completo antes de ser feito o deploy para produção.

# %%
# finalizando o modelo
final_gbr = finalize_model(tuned_gbr)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# Um aviso de cuidado. Uma vez que o modelo é finalizado usando a função finalize_model(), o dataset inteiro, incluindo a parte que havia sido separada anteriormente para teste, é usado para o treino.
#
# Dessa forma, se o modelo for usado para fazer previsões no conjunto de teste separado pelo PyCaret depois da função finalize ter sido utilizada, os resultados serão enganosos, pois você estará fazendo previsões em dados já vistos pelo modelo.
#
# Para demonstrar isso, vou usar o modelo finalizado com o predict_model() para comparar os resultados com os que tivemos na parte anterior.

# %%
# analisando a mudança nos resultados
predict_model(final_gbr);
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# ### 5.0 - Prevendo em dados novos
#
# A função predict_model() também é usada para prever em datasets nunca vistos antes. A única diferença é que para isso passaremos o parâmetro data.
#
# Dessa forma, passaremos como data os dados que ainda não foram vistos pelo modelo, separados anteriormente, no começo do projeto.
#
# Esse conjunto contém 10% do conjunto de dados original. Essa porção nunca foi exposta ao PyCaret, e é perfeita para simular novos dados reais que serão recebidos pelo modelo em produção.

# %%
# previsão em dados não vistos
unseen_predictions = predict_model(final_gbr, data=test, round=2)
unseen_predictions.head()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %% [markdown]
# A coluna label é adicionada ao conjunto novo. O Label é o valor previsto pelo modelo GBR. Caso você prefira ter o valor arrendodado, também é possível passar round como parâmetro em predict_model().

# %%
check_metric(unseen_predictions.charges, unseen_predictions.Label, 'R2')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...
